# %%
#%pip install pyglet==1.5.27

# %%
import os 
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make("CartPole-v1")
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 1674 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1088        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008400523 |
# |    clip_fraction        | 0.0977      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00174     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.63        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 53.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009887956 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.0908      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 40.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 886        |
# |    iterations           | 4          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00820558 |
# |    clip_fraction        | 0.0913     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.635     |
# |    explained_variance   | 0.214      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 20         |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0191    |
# |    value_loss           | 57.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 870         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008934768 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 67.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012544072 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 65.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004700306 |
# |    clip_fraction        | 0.034       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 52          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007483449 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.33        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00752    |
# |    value_loss           | 35.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 817         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003596732 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 23.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 812        |
# |    iterations           | 10         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00410303 |
# |    clip_fraction        | 0.0173     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.552     |
# |    explained_variance   | 0.498      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 39.5       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00553   |
# |    value_loss           | 66.2       |
# ----------------------------------------

# %%
episodes = 40
for n in range(1, episodes+1):
    observation = env.reset()
    done = False
    score = 0
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
env.close()
